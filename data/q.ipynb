# %%
import pandas as pd

df = pd.read_pickle('E:/Internships/Internship - Zidio(Data Analyst)/face punching/data/names.pkl')
print(f"Index of first occurrence of Muzammil's name is at index: {df.index('Muzammil')}")
last_occurrence = len(df) - 1 - df[::-1].index("Muzammil")
print(f"The last occurrence of Muzammil's names is at index: {last_occurrence} ")
len(df)
# Out:
# Index of first occurrence of Muzammil's name is at index: 200
# The last occurrence of Muzammil's names is at index: 399
# 500

# %%
df
# Out:
# ['Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
#  'Dharmendra Jha',
# ...

# %%
import pandas as pd

df = pd.read_xml('E:/Internships/Internship - Zidio(Data Analyst)/face punching/data/haarcascade_frontalface_default.xml')
df
# Out:
#                      type_id stageType featureType  height  width stageParams  \
# 0  opencv-cascade-classifier     BOOST        HAAR      24     24      \n
#
#   featureParams  stageNum  stages features
# 0        \n            25  \n       \n
